# %% [markdown]
# ## Langchain  Version V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)
response = model.invoke("Why we should take admission in GLA University?")

response
# Out:
# AIMessage(content="GLA University, located in Mathura, Uttar Pradesh, has emerged as a prominent private university in North India. Deciding to take admission there depends on your specific academic goals, career aspirations, and what you seek in a university experience.\n\nHere are several reasons why one might consider taking admission in GLA University:\n\n1.  **Strong Academic Programs & Faculty:**\n    *   **Diverse Offerings:** GLA offers a wide range of undergraduate, postgraduate, and doctoral programs across various disciplines like Engineering & Technology, Management, Pharmacy, Computer Applications, Law, Education, Humanities, and more.\n    *   **Experienced Faculty:** The university emphasizes having experienced and qualified faculty members, many with industry experience or advanced degrees, who focus on both theoretical knowledge and practical application.\n    *   **Industry-Relevant Curriculum:** Programs are often designed with industry input to ensure graduates are equipped with relevant skills and knowledge, making them more employable.\n\n2.  **Robust Infrastructure:**\n    *   **Modern Campus:** GLA boasts a large, well-maintained, and modern campus with state-of-the-art facilities.\n    *   **Well-Equipped Labs:** Especially for engineering and pharmacy programs, the university has advanced laboratories and workshops.\n    *   **Digital Library:** A comprehensive library with a vast collection of books, journals, and digital resources.\n    *   **Hostel Facilities:** Comfortable and secure on-campus accommodation for both male and female students.\n    *   **Sports & Recreation:** Facilities for various indoor and outdoor sports, gymnasiums, and recreational areas.\n\n3.  **Good Placement Record:**\n    *   **Dedicated Placement Cell:** GLA has a dedicated Corporate Resource Centre (CRC) that works actively to connect students with potential employers.\n    *   **Reputable Recruiters:** Many well-known national and multinational companies recruit from GLA University, particularly in engineering and management disciplines.\n    *   **Career Guidance:** The university often provides training in soft skills, interview preparation, and resume building to enhance students' employability.\n\n4.  **Accreditation & Rankings:**\n    *   **NAAC 'A' Grade:** GLA University is often accredited with an 'A' grade by NAAC (National Assessment and Accreditation Council), signifying quality education and institutional standards.\n    *   **NIRF Rankings:** It has consistently featured in the NIRF (National Institutional Ranking Framework) rankings in various categories (Engineering, Management, Pharmacy), which is a testament to its academic standing.\n    *   **UGC Approved:** As a university, it is recognized by the University Grants Commission (UGC).\n\n5.  **Focus on Practical Learning & Research:**\n    *   **Hands-on Experience:** Emphasis on practical training, internships, industrial visits, and project-based learning.\n    *   **Innovation & Research:** The university encourages research and innovation among students and faculty, with some departments having dedicated research centers.\n    *   **Industry Collaborations:** Tie-ups with various industries often lead to guest lectures, workshops, and real-world project opportunities.\n\n6.  **Vibrant Campus Life & Student Support:**\n    *   **Extracurricular Activities:** A plethora of student clubs, cultural events, technical fests, and sports competitions ensure a holistic development experience.\n    *   **Conducive Learning Environment:** A safe, disciplined, and green campus provides a focused environment for learning.\n    *   **Mentorship & Counseling:** Support systems like mentorship programs and counseling services are often available to help students adapt and succeed.\n\n7.  **Strategic Location:**\n    *   **Mathura:** While not a metro city, Mathura is historically and culturally significant, offering a unique environment. It's well-connected by ro ...
